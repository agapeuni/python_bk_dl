# %%
## 라이브러리 읽어 들이기
import numpy as np
from PIL import Image

# %%
# 이미지 파일 읽어 들이기

image = Image.open('./data/pict/sample.jpg', 'r')
# 이미지 파일 출력하기
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x103408F60>

# %%
# 이미지 크기 출력하기
image.size
# Out:
# (100, 100)

# %%
# 이미지 파일의 픽셀값 추출하기
image_px = np.array(image)
print(image_px)
# Out:
# [[[104  96 119]
#   [112 104 127]
#   [115 105 130]
#   ...,
#   [133 109 135]
#   [135 111 137]
#   [128 104 130]]
#
#  [[ 99  89 113]
#   [115 103 127]
#   [120 105 134]
#   ...,
#   [122  97 126]
#   [141 116 145]
#   [126 101 130]]
#
#  [[ 98  84 109]
#   [115  99 126]
#   [114  98 127]
#   ...,
#   [126  99 130]
#   [190 163 194]
#   [186 159 190]]
#
#  ...,
#  [[124 115 136]
#   [119 110 131]
#   [116 104 124]
#   ...,
#   [ 61  57  80]
#   [ 62  58  81]
#   [ 63  59  82]]
#
#  [[125 116 137]
#   [116 107 128]
#   [112 100 120]
#   ...,
#   [ 61  57  80]
#   [ 62  58  81]
#   [ 61  57  80]]
#
#  [[122 113 134]
#   [122 110 132]
#   [120 108 128]
#   ...,
#   [ 62  58  81]
#   [ 61  57  80]
#   [ 60  56  79]]]

# %%
# 이미지를 1차원 배열로 변환하기
image_flatten = image_px.flatten().astype(np.float32)/255.0
print(image_flatten)

# 이미지 픽셀값(배열)의 크기 출력하기
print(len(image_flatten))
# Out:
# [ 0.40784314  0.3764706   0.46666667 ...,  0.23529412  0.21960784
#   0.30980393]
# 30000

# %%
# 이미지를 그레이스케일로 변환하기
gray_image = image.convert('L')
# 이미지 파일을 출력하기
gray_image
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x1036B1C88>

# %%
# 이미지 파일을 픽셀값으로 변환하기
gray_image_px = np.array(gray_image)
print(gray_image_px)

# 이미지 픽셀값(배열)의 크기 출력하기
#print(len(gray_image_px))
# Out:
# [[101 109 110 ..., 119 121 114]
#  [ 94 109 112 ..., 107 126 111]
#  [ 91 106 106 ..., 110 174 170]
#  ...,
#  [120 115 109 ...,  60  61  62]
#  [121 112 105 ...,  60  61  60]
#  [118 116 113 ...,  61  60  59]]

# %%
# 이미지를 1차원 배열로 변환하기
gray_image_flatten = gray_image_px.flatten().astype(np.float32)/255.0
print(gray_image_flatten)

# 이미지 픽셀값(배열)의 크기 출력하기
print(len(gray_image_flatten))
# Out:
# [ 0.39607844  0.42745098  0.43137255 ...,  0.23921569  0.23529412
#   0.23137255]
# 10000

# %%
# 라이브러리 읽어 들이기
from PIL import ImageEnhance

# %%
# 이미지의 채도 조정하기
conv1 = ImageEnhance.Color(image)
conv1_image = conv1.enhance(0.5)
conv1_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1037124A8>

# %%
# 이미지의 명도 조정하기
conv2 = ImageEnhance.Brightness(image)
conv2_image = conv2.enhance(0.5)
conv2_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x103712A58>

# %%
# 이미지의 콘트라스트 조정하기
conv3 = ImageEnhance.Contrast(image)
conv3_image = conv3.enhance(0.5)
conv3_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x103712A20>

# %%
# 이미지의 날카로움 조정하기
conv4 = ImageEnhance.Sharpness(image)
conv4_image = conv4.enhance(2.0)
conv4_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x103712E80>

# %%
# 가공한 이미지 저장하기
conv4_image.save("./data/pict/conv_sample.jpg")
